# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.4'

# %% [markdown]
# * Podstawowe struktury danych(typy) : Series
# * Podstawowe struktury danych(typy) : DataFrame

# %% [markdown]
# #### Series

# %%
s = pd.Series(data=[3,2,4,6,12])
s
# Out:
# 0     3
# 1     2
# 2     4
# 3     6
# 4    12
# dtype: int64

# %%
s = pd.Series(data=[3.0,2,4,6,12], index=['a','b','c','d','e'], name='sample')
s
# Out:
# a     3.0
# b     2.0
# c     4.0
# d     6.0
# e    12.0
# Name: sample, dtype: float64

# %%
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
s = pd.Series(data=[3.0,np.nan,4,6,12], index=['a','b','c','d','e'], name='sample')
s
# Out:
# a     3.0
# b     NaN
# c     4.0
# d     6.0
# e    12.0
# Name: sample, dtype: float64

# %%
s = pd.Series(data=[True,False,False])
s
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
s =pd.Series(data=np.arange(10,20), index=pd.date_range(start='20200101', periods=10))
s
# Out:
# 2020-01-01    10
# 2020-01-02    11
# 2020-01-03    12
# 2020-01-04    13
# 2020-01-05    14
# 2020-01-06    15
# 2020-01-07    16
# 2020-01-08    17
# 2020-01-09    18
# 2020-01-10    19
# Freq: D, dtype: int32

# %%
list(s.index)
# Out:
# [Timestamp('2020-01-01 00:00:00', freq='D'),
#  Timestamp('2020-01-02 00:00:00', freq='D'),
#  Timestamp('2020-01-03 00:00:00', freq='D'),
#  Timestamp('2020-01-04 00:00:00', freq='D'),
#  Timestamp('2020-01-05 00:00:00', freq='D'),
#  Timestamp('2020-01-06 00:00:00', freq='D'),
#  Timestamp('2020-01-07 00:00:00', freq='D'),
#  Timestamp('2020-01-08 00:00:00', freq='D'),
#  Timestamp('2020-01-09 00:00:00', freq='D'),
#  Timestamp('2020-01-10 00:00:00', freq='D')]

# %%
s = pd.Series(data=['python','java','SQL'], name='languages')
s
# Out:
# 0    python
# 1      java
# 2       SQL
# Name: languages, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array(['python', 'java', 'SQL'], dtype=object)

# %%
s.dtypes
# Out:
# dtype('O')

# %%
s.shape
# Out:
# (3,)

# %%
price = pd.Series(data={'Apple':200,'CD-Projekt':500,'Amazon':1000, 'KGHM':np.nan})
price
# Out:
# Apple          200.0
# CD-Projekt     500.0
# Amazon        1000.0
# KGHM             NaN
# dtype: float64

# %%
price['CD-Projekt']
# Out:
# 500.0

# %%
price[1]
# Out:
# 500.0

# %%
price.count()
# Out:
# 3

# %%
price.value_counts()
# Out:
# 200.0     1
# 500.0     1
# 1000.0    1
# dtype: int64

# %%
price.sum()
# Out:
# 1700.0

# %%
price.min()
# Out:
# 200.0

# %%
price.max()
# Out:
# 1000.0

# %%
price.std()
# Out:
# 404.145188432738

# %%
price.describe().T
# Out:
# count       3.000000
# mean      566.666667
# std       404.145188
# min       200.000000
# 25%       350.000000
# 50%       500.000000
# 75%       750.000000
# max      1000.000000
# dtype: float64

# %%
price.value_counts(dropna=False)
# Out:
# 200.0     1
# 500.0     1
# 1000.0    1
# NaN       1
# dtype: int64

# %%
price.nlargest(2)
# Out:
# Amazon        1000.0
# CD-Projekt     500.0
# dtype: float64

# %%
price.nsmallest(2)
# Out:
# Apple         200.0
# CD-Projekt    500.0
# dtype: float64

# %%
price.rank()
# Out:
# Apple         1.0
# CD-Projekt    2.0
# Amazon        3.0
# KGHM          NaN
# dtype: float64

# %%
price.sort_values(ascending=False)
# Out:
# Amazon        1000.0
# CD-Projekt     500.0
# Apple          200.0
# KGHM             NaN
# dtype: float64

# %%
pricePLN = price.apply(lambda x: x * 3.8)

# %%
pricePLN
# Out:
# Apple          760.0
# CD-Projekt    1900.0
# Amazon        3800.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# #### DataFrame

# %%
df = pd.DataFrame([12,12,230])
df
# Out:
#      0
# 0   12
# 1   12
# 2  230

# %%
df = pd.DataFrame([12,12,230], index=['first','second','third'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third     230

# %%
df = pd.DataFrame(data={'wig20':['PKN ORLEN', "PKO BP"],'mwig40':['Amica', 'Bosch']})

# %%
df
# Out:
#        wig20 mwig40
# 0  PKN ORLEN  Amica
# 1     PKO BP  Bosch

# %%
df.columns
# Out:
# Index(['wig20', 'mwig40'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df.values
# Out:
# array([['PKN ORLEN', 'Amica'],
#        ['PKO BP', 'Bosch']], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   wig20   2 non-null      object
#  1   mwig40  2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes

# %%
df.describe()
# Out:
#             wig20 mwig40
# count           2      2
# unique          2      2
# top     PKN ORLEN  Bosch
# freq            1      1

# %%
df.describe().T
# Out:
#        count unique        top freq
# wig20      2      2  PKN ORLEN    1
# mwig40     2      2      Bosch    1

# %%
df
# Out:
#        wig20 mwig40
# 0  PKN ORLEN  Amica
# 1     PKO BP  Bosch

# %%
df['wig20']
# Out:
# 0    PKN ORLEN
# 1       PKO BP
# Name: wig20, dtype: object

# %%
type(df['wig20'])
# Out:
# pandas.core.series.Series

# %%
df[['wig20']]
# Out:
#        wig20
# 0  PKN ORLEN
# 1     PKO BP

# %%
type(df[['wig20']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns =['a','b']

# %%
df.columns
# Out:
# Index(['a', 'b'], dtype='object')

# %%
df.a
# Out:
# 0    PKN ORLEN
# 1       PKO BP
# Name: a, dtype: object

# %%
df['d'] = np.nan

# %%
df
# Out:
#            a      b   d
# 0  PKN ORLEN  Amica NaN
# 1     PKO BP  Bosch NaN

# %%
df.iloc[0]
# Out:
# a    PKN ORLEN
# b        Amica
# d          NaN
# Name: 0, dtype: object

# %%
df.loc[0,'b']
# Out:
# 'Amica'

# %%
df.loc[:,'b']
# Out:
# 0    Amica
# 1    Bosch
# Name: b, dtype: object

# %%
df.iloc[:,2]
# Out:
# 0   NaN
# 1   NaN
# Name: d, dtype: float64

# %%
df.iloc[1,1]
# Out:
# 'Bosch'

# %%
import pandas as pd
import numpy as np


print(f'Numpy: {np.__version__}')
print(f'Pandas: {pd.__version__}')
# Out:
# Numpy: 1.20.1
# Pandas: 1.2.4

# %%
def fetch_financial_data(company='AMZN'):
    """Pobiera dane dotyczące notowań spółek na giełdzie
    według symboli na serwisie stooq.pl """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2021-11-01 to 2016-11-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
df
# Out:
#                 Open      High        Low     Close   Volume
# Date
# 2021-11-01  3361.800  3375.860  3292.0200  3318.110  3608879
# 2021-10-29  3300.020  3374.820  3273.3200  3372.430  6486077
# 2021-10-28  3402.095  3479.000  3386.0000  3446.570  5708733
# 2021-10-27  3388.000  3437.000  3371.4534  3392.490  2702224
# 2021-10-26  3349.510  3416.120  3343.9800  3376.070  2698342
# ...              ...       ...        ...       ...      ...
# 2016-11-09   764.000   777.500   760.0900   771.880  8485151
# 2016-11-08   784.970   791.740   779.1000   787.750  3293216
# 2016-11-07   771.640   787.732   770.9400   784.935  5572545
# 2016-11-04   762.790   766.000   753.2300   755.050  5122103
# 2016-11-03   765.050   777.000   764.0000   767.030  3872496
#
# [1257 rows x 5 columns]

# %%
df.head()
# Out:
#                 Open     High        Low    Close   Volume
# Date
# 2021-11-01  3361.800  3375.86  3292.0200  3318.11  3608879
# 2021-10-29  3300.020  3374.82  3273.3200  3372.43  6486077
# 2021-10-28  3402.095  3479.00  3386.0000  3446.57  5708733
# 2021-10-27  3388.000  3437.00  3371.4534  3392.49  2702224
# 2021-10-26  3349.510  3416.12  3343.9800  3376.07  2698342

# %%
df.head(10)
# Out:
#                 Open       High        Low    Close   Volume
# Date
# 2021-11-01  3361.800  3375.8600  3292.0200  3318.11  3608879
# 2021-10-29  3300.020  3374.8200  3273.3200  3372.43  6486077
# 2021-10-28  3402.095  3479.0000  3386.0000  3446.57  5708733
# 2021-10-27  3388.000  3437.0000  3371.4534  3392.49  2702224
# 2021-10-26  3349.510  3416.1200  3343.9800  3376.07  2698342
# 2021-10-25  3335.000  3347.7997  3297.7000  3320.37  2225956
# 2021-10-22  3421.000  3429.8400  3331.3000  3335.55  3139053
# 2021-10-21  3414.250  3440.2800  3403.0000  3435.01  1881385
# 2021-10-20  3452.660  3462.8600  3400.3700  3415.06  2139777
# 2021-10-19  3434.290  3454.6900  3422.0000  3444.15  2386079

# %%
df.tail(12)
# Out:
#               Open     High      Low    Close    Volume
# Date
# 2016-11-18  761.00  767.740  757.644  760.160   4227993
# 2016-11-17  749.32  757.500  748.000  756.390   3503295
# 2016-11-16  739.88  749.870  735.610  746.490   3545800
# 2016-11-15  730.00  746.780  725.990  743.240   6755785
# 2016-11-14  745.51  746.000  710.100  719.070   7321344
# 2016-11-11  735.73  743.260  728.900  739.010   6409768
# 2016-11-10  778.81  778.830  717.700  742.380  12678109
# 2016-11-09  764.00  777.500  760.090  771.880   8485151
# 2016-11-08  784.97  791.740  779.100  787.750   3293216
# 2016-11-07  771.64  787.732  770.940  784.935   5572545
# 2016-11-04  762.79  766.000  753.230  755.050   5122103
# 2016-11-03  765.05  777.000  764.000  767.030   3872496

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count  1257.000000  1257.000000  1257.000000  1257.000000  1.257000e+03
# mean   1998.798276  2019.188893  1975.830599  1998.129320  4.295768e+06
# std     870.493916   880.376998   859.510111   869.630746  2.069112e+06
# min     730.000000   743.260000   710.100000   719.070000  8.813370e+05
# 25%    1385.930000  1419.720000  1355.000000  1390.000000  2.896526e+06
# 50%    1801.010000  1818.980000  1784.510000  1800.800000  3.689272e+06
# 75%    3054.860000  3090.960000  2996.000000  3046.260000  5.114403e+06
# max    3744.000000  3773.078200  3696.792900  3731.410000  1.655260e+07

# %%
df.describe().T
# Out:
#          count          mean           std        min         25%         50%  \
# open    1257.0  1.998798e+03  8.704939e+02     730.00     1385.93     1801.01
# high    1257.0  2.019189e+03  8.803770e+02     743.26     1419.72     1818.98
# low     1257.0  1.975831e+03  8.595101e+02     710.10     1355.00     1784.51
# close   1257.0  1.998129e+03  8.696307e+02     719.07     1390.00     1800.80
# volume  1257.0  4.295768e+06  2.069112e+06  881337.00  2896526.00  3689272.00
#
#                75%           max
# open       3054.86  3.744000e+03
# high       3090.96  3.773078e+03
# low        2996.00  3.696793e+03
# close      3046.26  3.731410e+03
# volume  5114403.00  1.655260e+07

# %%
df = df.head(10)
df
# Out:
#                 open       high        low    close   volume
# Date
# 2021-11-01  3361.800  3375.8600  3292.0200  3318.11  3608879
# 2021-10-29  3300.020  3374.8200  3273.3200  3372.43  6486077
# 2021-10-28  3402.095  3479.0000  3386.0000  3446.57  5708733
# 2021-10-27  3388.000  3437.0000  3371.4534  3392.49  2702224
# 2021-10-26  3349.510  3416.1200  3343.9800  3376.07  2698342
# 2021-10-25  3335.000  3347.7997  3297.7000  3320.37  2225956
# 2021-10-22  3421.000  3429.8400  3331.3000  3335.55  3139053
# 2021-10-21  3414.250  3440.2800  3403.0000  3435.01  1881385
# 2021-10-20  3452.660  3462.8600  3400.3700  3415.06  2139777
# 2021-10-19  3434.290  3454.6900  3422.0000  3444.15  2386079

# %%
df['open']
# Out:
# Date
# 2021-11-01    3361.800
# 2021-10-29    3300.020
# 2021-10-28    3402.095
# 2021-10-27    3388.000
# 2021-10-26    3349.510
# 2021-10-25    3335.000
# 2021-10-22    3421.000
# 2021-10-21    3414.250
# 2021-10-20    3452.660
# 2021-10-19    3434.290
# Name: open, dtype: float64

# %%
df.open
# Out:
# Date
# 2021-11-01    3361.800
# 2021-10-29    3300.020
# 2021-10-28    3402.095
# 2021-10-27    3388.000
# 2021-10-26    3349.510
# 2021-10-25    3335.000
# 2021-10-22    3421.000
# 2021-10-21    3414.250
# 2021-10-20    3452.660
# 2021-10-19    3434.290
# Name: open, dtype: float64

# %%
df[['open','close']]
# Out:
#                 open    close
# Date
# 2021-11-01  3361.800  3318.11
# 2021-10-29  3300.020  3372.43
# 2021-10-28  3402.095  3446.57
# 2021-10-27  3388.000  3392.49
# 2021-10-26  3349.510  3376.07
# 2021-10-25  3335.000  3320.37
# 2021-10-22  3421.000  3335.55
# 2021-10-21  3414.250  3435.01
# 2021-10-20  3452.660  3415.06
# 2021-10-19  3434.290  3444.15

# %%
df.iloc[:,0]
# Out:
# Date
# 2021-11-01    3361.800
# 2021-10-29    3300.020
# 2021-10-28    3402.095
# 2021-10-27    3388.000
# 2021-10-26    3349.510
# 2021-10-25    3335.000
# 2021-10-22    3421.000
# 2021-10-21    3414.250
# 2021-10-20    3452.660
# 2021-10-19    3434.290
# Name: open, dtype: float64

# %%
df.iloc[:,[0,3]]
# Out:
#                 open    close
# Date
# 2021-11-01  3361.800  3318.11
# 2021-10-29  3300.020  3372.43
# 2021-10-28  3402.095  3446.57
# 2021-10-27  3388.000  3392.49
# 2021-10-26  3349.510  3376.07
# 2021-10-25  3335.000  3320.37
# 2021-10-22  3421.000  3335.55
# 2021-10-21  3414.250  3435.01
# 2021-10-20  3452.660  3415.06
# 2021-10-19  3434.290  3444.15

# %%
df.iloc[:,[-1]]
# Out:
#              volume
# Date
# 2021-11-01  3608879
# 2021-10-29  6486077
# 2021-10-28  5708733
# 2021-10-27  2702224
# 2021-10-26  2698342
# 2021-10-25  2225956
# 2021-10-22  3139053
# 2021-10-21  1881385
# 2021-10-20  2139777
# 2021-10-19  2386079

# %%
df.iloc[0]
# Out:
# open         3361.80
# high         3375.86
# low          3292.02
# close        3318.11
# volume    3608879.00
# Name: 2021-11-01 00:00:00, dtype: float64

# %%
df.iloc[:3]
# Out:
#                 open     high      low    close   volume
# Date
# 2021-11-01  3361.800  3375.86  3292.02  3318.11  3608879
# 2021-10-29  3300.020  3374.82  3273.32  3372.43  6486077
# 2021-10-28  3402.095  3479.00  3386.00  3446.57  5708733

# %%
df.loc['2021-11-01']
# Out:
#               open     high      low    close   volume
# Date
# 2021-11-01  3361.8  3375.86  3292.02  3318.11  3608879

# %%
df.loc['2021-11-01':'2021-10-25']
# Out:
#                 open       high        low    close   volume
# Date
# 2021-11-01  3361.800  3375.8600  3292.0200  3318.11  3608879
# 2021-10-29  3300.020  3374.8200  3273.3200  3372.43  6486077
# 2021-10-28  3402.095  3479.0000  3386.0000  3446.57  5708733
# 2021-10-27  3388.000  3437.0000  3371.4534  3392.49  2702224
# 2021-10-26  3349.510  3416.1200  3343.9800  3376.07  2698342
# 2021-10-25  3335.000  3347.7997  3297.7000  3320.37  2225956

# %%
df = fetch_financial_data('UBER')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 626 entries, 2021-11-01 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    626 non-null    float64
#  1   High    626 non-null    float64
#  2   Low     626 non-null    float64
#  3   Close   626 non-null    float64
#  4   Volume  626 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 29.3 KB

# %%
df.head()
# Out:
#              Open     High      Low  Close    Volume
# Date
# 2021-11-01  44.07  45.0250  43.6500  44.36  20983925
# 2021-10-29  44.49  44.8000  43.5700  43.82  18283203
# 2021-10-28  45.00  45.4117  44.3833  44.62  14768789
# 2021-10-27  46.47  46.5500  44.1650  44.73  26999752
# 2021-10-26  46.28  47.6900  45.8600  46.02  19491761

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  626.000000  626.000000  626.000000  626.000000  6.260000e+02
# mean    40.443041   41.213362   39.565637   40.391933  2.341171e+07
# std      9.696223    9.773993    9.556668    9.636323  1.704821e+07
# min     15.960000   17.800000   13.710000   14.820000  3.380003e+06
# 25%     32.487500   33.085000   31.602500   32.555000  1.359260e+07
# 50%     39.685000   40.272500   38.785000   39.770000  1.922605e+07
# 75%     47.985000   49.157500   47.285000   48.037500  2.820308e+07
# max     63.250000   64.050000   60.800000   63.180000  1.863225e+08

# %%
df.head(3)
# Out:
#              Open     High      Low  Close    Volume
# Date
# 2021-11-01  44.07  45.0250  43.6500  44.36  20983925
# 2021-10-29  44.49  44.8000  43.5700  43.82  18283203
# 2021-10-28  45.00  45.4117  44.3833  44.62  14768789

# %%
df['Average'] = (df.Open + df.Close) /2

# %%
df.head()
# Out:
#              Open     High      Low  Close    Volume  Average
# Date
# 2021-11-01  44.07  45.0250  43.6500  44.36  20983925   44.215
# 2021-10-29  44.49  44.8000  43.5700  43.82  18283203   44.155
# 2021-10-28  45.00  45.4117  44.3833  44.62  14768789   44.810
# 2021-10-27  46.47  46.5500  44.1650  44.73  26999752   45.600
# 2021-10-26  46.28  47.6900  45.8600  46.02  19491761   46.150

# %%
df = df.sort_index()
df.head()
# Out:
#              Open   High    Low  Close     Volume  Average  Close_shift
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785          NaN
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945    -0.107529
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135     0.077089
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330     0.033283
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240     0.041414

# %%
df['Close_shift'] = df[['Close']].shift(1)

# %%
df['Daily_change'] = df.Close / df.Close_shift - 1

# %%
df
# Out:
#              Open     High      Low  Close     Volume  Average  Close_shift  \
# Date
# 2019-05-10  42.00  45.0000  41.0600  41.57  186322536   41.785          NaN
# 2019-05-13  38.79  39.2400  36.0800  37.10   79442420   37.945        41.57
# 2019-05-14  38.31  39.9600  36.8500  39.96   46661147   39.135        37.10
# 2019-05-15  39.37  41.8800  38.9500  41.29   36086065   40.330        39.96
# 2019-05-16  41.48  44.0600  41.2500  43.00   38115524   42.240        41.29
# ...           ...      ...      ...    ...        ...      ...          ...
# 2021-10-26  46.28  47.6900  45.8600  46.02   19491761   46.150        45.72
# 2021-10-27  46.47  46.5500  44.1650  44.73   26999752   45.600        46.02
# 2021-10-28  45.00  45.4117  44.3833  44.62   14768789   44.810        44.73
# 2021-10-29  44.49  44.8000  43.5700  43.82   18283203   44.155        44.62
# 2021-11-01  44.07  45.0250  43.6500  44.36   20983925   44.215        43.82
#
#             Daily_change
# Date
# ...

# %%
df.Daily_change.min()
# Out:
# -0.21628767847699626

# %%
df.Daily_change.max()
# Out:
# 0.3825910931174088

# %%
import seaborn as sns
sns.set()
df.Daily_change.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df
# Out:
#              Open     High      Low  Close     Volume  Average  Close_shift  \
# Date
# 2019-05-10  42.00  45.0000  41.0600  41.57  186322536   41.785          NaN
# 2019-05-13  38.79  39.2400  36.0800  37.10   79442420   37.945        41.57
# 2019-05-14  38.31  39.9600  36.8500  39.96   46661147   39.135        37.10
# 2019-05-15  39.37  41.8800  38.9500  41.29   36086065   40.330        39.96
# 2019-05-16  41.48  44.0600  41.2500  43.00   38115524   42.240        41.29
# ...           ...      ...      ...    ...        ...      ...          ...
# 2021-10-26  46.28  47.6900  45.8600  46.02   19491761   46.150        45.72
# 2021-10-27  46.47  46.5500  44.1650  44.73   26999752   45.600        46.02
# 2021-10-28  45.00  45.4117  44.3833  44.62   14768789   44.810        44.73
# 2021-10-29  44.49  44.8000  43.5700  43.82   18283203   44.155        44.62
# 2021-11-01  44.07  45.0250  43.6500  44.36   20983925   44.215        43.82
#
#             Daily_change
# Date
# ...

# %%
df_positive = df[df.Daily_change > 0]
df_positive
# Out:
#              Open    High      Low  Close    Volume  Average  Close_shift  \
# Date
# 2019-05-14  38.31  39.960  36.8500  39.96  46661147   39.135        37.10
# 2019-05-15  39.37  41.880  38.9500  41.29  36086065   40.330        39.96
# 2019-05-16  41.48  44.060  41.2500  43.00  38115524   42.240        41.29
# 2019-05-24  41.28  41.510  40.5000  41.51   8786751   41.395        40.47
# 2019-05-31  41.15  41.570  39.4100  40.41  23209848   40.780        39.80
# ...           ...     ...      ...    ...       ...      ...          ...
# 2021-10-15  47.91  48.840  47.3400  48.36  20581670   48.135        47.28
# 2021-10-21  45.97  47.540  45.5200  46.47  15741030   46.220        46.00
# 2021-10-25  45.67  46.070  45.0173  45.72  12955477   45.695        45.51
# 2021-10-26  46.28  47.690  45.8600  46.02  19491761   46.150        45.72
# 2021-11-01  44.07  45.025  43.6500  44.36  20983925   44.215        43.82
#
#             Daily_change
# Date
# 2019-05-14      0.077089
# ...

# %%
df_negative = df[df.Daily_change < 0]
df_negative
# Out:
#              Open     High      Low  Close    Volume  Average  Close_shift  \
# Date
# 2019-05
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330        39.96
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240        41.29
# ...           ...    ...    ...    ...        ...      ...          ...
# 2019-12-24  30.33  30.84  30.11  30.44   12938593   30.385        30.33
# 2019-12-26  30.47  30.79  30.03  30.67   22224500   30.570        30.44
# 2019-12-27  30.80  31.06  30.17  30.17   18465965   30.485        30.67
# 2019-12-30  30.13  30.20  29.35  29.74   18812846   29.935        30.17
# 2019-12-31  29.11  29.95  28.90  29.74   16233064   29.425        29.74
#
#             Daily_change
# Date
# 2019-05-10           NaN
# 2019-05-13     -0.107529
# ...

# %%
df[df.index.day == 1]
# Out:
#               Open     High      Low  Close    Volume  Average  Close_shift  \
# Date
# 2019-07-01  46.980  47.0400  44.0600  44.27  17739998  45.6250        46.38
# 2019-08-01  42.140  42.5355  41.0000  41.31   7349740  41.7250        42.14
# 2019-10-01  30.370  30.5100  28.6500  29.15  13448055  29.7600        30.47
# 2019-11-01  31.450  31.7000  30.7412  31.37  10460430  31.4100        31.50
# 2020-04-01  26.500  26.7670  24.8101  25.42  38538381  25.9600        27.92
# 2020-05-01  29.130  29.7200  28.3250  28.39  19290192  28.7600        30.27
# 2020-06-01  35.640  36.3900  35.1600  35.82  21893806  35.7300        36.32
# 2020-07-01  30.960  31.2650  30.1622  30.43  13611544  30.6950        31.08
# 2020-09-01  33.450  34.5100  33.1450  34.30  16026170  33.8750        33.63
# 2020-10-01  36.860  37.8282  36.5800  37.14  19187502  37.0000        36.48
# 2020-12-01  50.000  51.4100  49.0700  49.63  20619101  49.8150        49.66
# ...

# %%
df = fetch_financial_data('FB')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2021-11-01 to 2016-11-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
df.to_csv('fb.csv')

# %%
df_nov = df[(df.index.month == 11) & (df.index.year == 2019)]
df_nov
# Out:
#                Open     High      Low   Close    Volume
# Date
# 2019-11-29  201.600  203.800  201.210  201.64   7985231
# 2019-11-27  199.900  203.140  199.420  202.00  12729462
# 2019-11-26  200.000  200.150  198.039  198.97  11748664
# 2019-11-25  199.515  200.970  199.250  199.79  15286442
# 2019-11-22  198.380  199.300  197.620  198.82   9959817
# 2019-11-21  197.420  199.090  196.860  197.93  12130985
# 2019-11-20  198.580  199.590  195.430  197.51  12370240
# 2019-11-19  197.400  200.000  196.860  199.32  19070291
# 2019-11-18  194.560  198.630  193.050  197.40  16176107
# 2019-11-15  194.260  195.300  193.380  195.10  11530232
# 2019-11-14  192.930  194.030  191.450  193.15   9059897
# 2019-11-13  194.700  195.700  192.740  193.19  11009800
# 2019-11-12  190.000  195.060  189.740  194.47  17615454
# 2019-11-11  189.930  190.080  188.540  189.61   8637768
# 2019-11-08  190.000  192.340  189.700  190.84  10764784
# 2019-11-07  191.910  193.440  189.470  190.42  13472998
# ...

# %%
df_nov.to_csv('fb_nov.csv')

# %%
new_df = pd.read_csv('fb_nov.csv', index_col=0)
new_df
# Out:
#                Open     High      Low   Close    Volume
# Date
# 2019-11-29  201.600  203.800  201.210  201.64   7985231
# 2019-11-27  199.900  203.140  199.420  202.00  12729462
# 2019-11-26  200.000  200.150  198.039  198.97  11748664
# 2019-11-25  199.515  200.970  199.250  199.79  15286442
# 2019-11-22  198.380  199.300  197.620  198.82   9959817
# 2019-11-21  197.420  199.090  196.860  197.93  12130985
# 2019-11-20  198.580  199.590  195.430  197.51  12370240
# 2019-11-19  197.400  200.000  196.860  199.32  19070291
# 2019-11-18  194.560  198.630  193.050  197.40  16176107
# 2019-11-15  194.260  195.300  193.380  195.10  11530232
# 2019-11-14  192.930  194.030  191.450  193.15   9059897
# 2019-11-13  194.700  195.700  192.740  193.19  11009800
# 2019-11-12  190.000  195.060  189.740  194.47  17615454
# 2019-11-11  189.930  190.080  188.540  189.61   8637768
# 2019-11-08  190.000  192.340  189.700  190.84  10764784
# 2019-11-07  191.910  193.440  189.470  190.42  13472998
# ...
