# %%
import pathlib
help(pathlib)
# Out:
# Help on module pathlib:
#
# NAME
#     pathlib
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/pathlib
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.object
#         PurePath
#             Path
#                 PosixPath(Path, PurePosixPath)
#                 WindowsPath(Path, PureWindowsPath)
#             PurePosixPath
#             PureWindowsPath
#
#     class Path(PurePath)
#      |  Path(*args, **kwargs)
#      |
#      |  PurePath subclass that can make system calls.
#      |
#      |  Path represents a filesystem path but unlike PurePath, also offers
#      |  methods to do system calls on path objects. Depending on your system,
# ...

# %% [markdown]
# ### 1

# %%
help(pathlib.Path.cwd)
pathlib.Path.cwd()
# Out:
# Help on method cwd in module pathlib:
#
# cwd() method of builtins.type instance
#     Return a new path pointing to the current working directory
#     (as returned by os.getcwd()).
# WindowsPath('C:/Users/marek.barul/Desktop/Python pliki/Modules/pathlib')

# %% [markdown]
# ### 2

# %%
help(pathlib.Path.home)
pathlib.Path.home()
# Out:
# Help on method home in module pathlib:
#
# home() method of builtins.type instance
#     Return a new path pointing to the user's home directory (as
#     returned by os.path.expanduser('~')).
# WindowsPath('C:/Users/marek.barul')

# %% [markdown]
# ### 3

# %%
#help(pathlib.Path)
path = pathlib.Path('/root/reports/2020/01/sales.csv')
print(path)
# Out:
# \root\reports\2020\01\sales.csv

# %% [markdown]
# ### 4

# %%
help(pathlib.Path.joinpath)
home = pathlib.Path.home()
cwd = pathlib.Path.cwd()
track = 'reports/2020/01/sales.csv'
path1 = pathlib.Path.joinpath(home,'reports/2020/01/sales.csv')
path2 = cwd / 'reports/2020/01/sales.csv'

print(path3)
print(path1)
print(path2)
# Out:
# Help on function joinpath in module pathlib:
#
# joinpath(self, *args)
#     Combine this path with one or several arguments, and return a
#     new path representing either a subpath (if all arguments are relative
#     paths) or a totally different path (if one of the arguments is
#     anchored).
#
# C:\Users\marek.barul\reports\2020\01\sales.csv
# C:\Users\marek.barul\reports\2020\01\sales.csv
# C:\Users\marek.barul\Desktop\Python pliki\Modules\pathlib\reports\2020\01\sales.csv

# %% [markdown]
# ### 5

# %%
home = pathlib.Path.home()
path = home / 'reports/2020/01/sales.csv'
print(path.parent)
print(path.name)
print(path.stem)
print(path.suffix)
print(path.parts)
# Out:
# C:\Users\marek.barul\reports\2020\01
# sales.csv
# sales
# .csv
# ('C:\\', 'Users', 'marek.barul', 'reports', '2020', '01', 'sales.csv')

# %% [markdown]
# ### 6

# %%
home = pathlib.Path.home()
path = home / 'reports/2020/01/sales.csv'

for parent in path.parents:
    print(parent)
# Out:
# C:\Users\marek.barul\reports\2020\01
# C:\Users\marek.barul\reports\2020
# C:\Users\marek.barul\reports
# C:\Users\marek.barul
# C:\Users
# C:\

# %% [markdown]
# ### 7
